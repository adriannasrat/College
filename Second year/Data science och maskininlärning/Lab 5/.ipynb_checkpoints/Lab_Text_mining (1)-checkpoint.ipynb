# %% [markdown]
# # **Linguistic Features:**
#
# Text: The original word text.
#
# Lemma: The base form of the word.
#
# POS: The simple POS part-of-speech tag.
#
# Tag: The detailed part-of-speech tag. ("DT" for determiner, "VBZ" for verb, "NN" for noun)
#
# Dep: Syntactic dependency, i.e. the relation between tokens.
#
# Shape: The word shape – capitalization, punctuation, digits.
#
# is alpha: Is the token an alphabetic character?
#
# is stop: Is the token part of a stop list, i.e. the most common words of the language?

# %%
# Spacy, nltk, textblob, pandas, numpy, matplotlib, scikit-learn
# Download this in prompt: python -m spacy download en
# There are a few more downloads below

import spacy

nlp_model = spacy.load("en_core_web_sm")

# Create a Doc object
doc = nlp_model(u"Apple is one of the biggest companies in the world")
# Out:
# C:\Users\vpp\AppData\Local\anaconda3\Lib\site-packages\requests\__init__.py:109: RequestsDependencyWarning: urllib3 (2.0.4) or chardet (4.0.0)/charset_normalizer (3.2.0) doesn't match a supported version!
#   warnings.warn(
# C:\Users\vpp\AppData\Local\anaconda3\Lib\site-packages\spacy\util.py:910: UserWarning: [W095] Model 'en_core_web_sm' (3.5.0) was trained with spaCy v3.5.0 and may not be 100% compatible with the current version (3.7.4). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)

# %%
# Print each token separately
for token in doc:
    print(token.text, token.pos_, token.dep_, token.is_stop)
# Out:
# Apple PROPN nsubj False
# is AUX ROOT True
# one NUM attr True
# of ADP prep True
# the DET det True
# biggest ADJ amod False
# companies NOUN pobj False
# in ADP prep True
# the DET det True
# world NOUN pobj False

# %%
doc[2].tag_
# Out:
# 'CD'

# %%
# tag_; text; lemma_ ; pos_ ; 
 #   tag_; shape_; is_alpha;
 #   is_stop

# %%
doc1 = nlp_model(u'Although commmonly attributed to John Lennon from his song "Beautiful Boy", \
the phrase "Life is what happens to us while we are making other plans" was written by \
cartoonist Allen Saunders and published in Reader\'s Digest in 1957, when Lennon was 17.')
doc1
# Out:
# Although commmonly attributed to John Lennon from his song "Beautiful Boy", the phrase "Life is what happens to us while we are making other plans" was written by cartoonist Allen Saunders and published in Reader's Digest in 1957, when Lennon was 17.

# %%
life_quote = doc1[16:30]
print(life_quote)
# Out:
# "Life is what happens to us while we are making other plans"

# %%
# span is a slice of document or sentence
type(life_quote)
# Out:
# spacy.tokens.span.Span

# %% [markdown]
# # Tokenization

# %%
mystring = nlp_model(u"One is a number")
print(mystring)

# Create a string that includes opening and closing quotation marks
mystring1 = nlp_model(u"We're here to help! email support@oursite.com or visit us at http://www.oursite.com!")
print(mystring1)
# Out:
# One is a number
# We're here to help! email support@oursite.com or visit us at http://www.oursite.com!

# %%
# Explore tokens
doc3 = nlp_model(mystring)

for t in doc3:
    print(t.text)
# Out:
# One
# is
# a
# number

# %%
doc4 = nlp_model(mystring1)

for token in doc4:
    print(token)
# Out:
# We
# 're
# here
# to
# help
# !
# email
# support@oursite.com
# or
# visit
# us
# at
# http://www.oursite.com
# !

# %%
# count of tokens
len(doc4)
# Out:
# 14

# %% [markdown]
# # Named entity

# %%
doc5 = nlp_model(u'Apple is one of the fruits')

for token in doc5:
    print(token.text, end=' | ')

print('\n----')

for ent in doc5.ents:
    print(ent.text+' - '+ent.label_)
# Out:
# Apple | is | one | of | the | fruits |
# ----
# Apple - ORG

# %%
# Lemmatization/stemming

doc6 = nlp_model(u"Mapping a GIS tool")

for token in doc6:
    print(token.text, '\t', token.pos_, '\t', token.lemma_)
# Out:
# Mapping 	 NOUN 	 mapping
# a 	 DET 	 a
# GIS 	 PROPN 	 GIS
# tool 	 NOUN 	 tool

# %%
# Stop words
print(nlp_model.Defaults.stop_words)
# Out:
# {'amount', 'have', 'fifteen', 'latterly', 'myself', 'now', 'a', 'her', 'see', 'one', '’ve', 'do', 'via', 'will', 'so', 'us', 'up', 'off', 'yours', "'s", 'above', 'here', 'make', 'whereupon', 'that', 'fifty', 'during', 'its', 'sixty', 'take', 're', 'often', 'last', 'someone', 'nine', 'elsewhere', 'am', "'ll", 'put', 'nowhere', 'about', 'still', 'five', 'next', 'whither', 'get', 'yet', 'without', '’re', 'else', 'say', 'of', 'own', 'go', 'using', 'anyhow', 'onto', 'first', 'if', 'regarding', 'seem', 'within', "n't", 'what', 'itself', 'whether', 'though', 'it', 'because', 'out', 'such', 'seemed', 'name', 'under', 'keep', 'full', 'anywhere', 'might', 'while', 'alone', 'behind', 'at', 'becomes', 'has', 'their', 'he', 'which', 'eleven', 'sometime', 'since', 'also', 'upon', 'please', 'can', 'between', 'hence', 'part', 'would', 'many', 'should', '’m', 'every', 'i', 'then', 'used', "'d", 'any', 'only', 'this', 'once', 'did', 'whence', 'six', 'otherwise', 'never', 'with', 'cannot', 'made', 'the', 'due', 'third', 'again', 'done', 'twenty', 'doing', 'hereafter', 'either', 'really', 'seeming', 'neither', 'our', 'whatever', 'ten', 'always', 'very', 'front', 'beside', 'various', 'may', 'wherever', 'other', 'does', 'unless', 'where', 'although', 'moreover', 'well', 'latter', 'were', 'show', 'just', 'call', 'become', 'my', 'move', 'hereupon', 'rather', 'than', 'throughout', 'beyond', 'whose', 'into', 'ever', 'less', 'too', '’ll', 'nor', 'per', 'besides', 'be', 'thereby', 'before', 'across', 'you', 'being', '‘m', 'whereafter', 'over', 'she', 'thru', 'not', 'wherein', 'even', 'mine', 'perhaps', 'indeed', 'everyone', 'two', 'whom', 'whole', 'beforehand', 'these', 'along', 'further', 'we', 'or', '‘s', 'therefore', 'therein', 'nothing', 'toward', 'through', 'from', '‘d', 'whereby', 'whoever', 'are', 'everything', 'was', 'down', 'top', 'already', 'as', 'give', 'mostly', 'none', 'towards', "'ve", "'m", 'something', 'them', 'nobody', 'back', 'until', 'ours', 'why', '‘ll', 'afterwards', 'another', 'everywhere', 'more', 'became', 'least', 'but', 'much', 'each', 'yourself', 'hereby', 'n’t', 'sometimes', 'three', 'formerly', 'by', 'no', 'below', 'both', 'empty', 'enough', 'himself', 'few', 'how', '’s', 'yourselves', 'others', 'all', 'nevertheless', 'they', '’d', 'your', 'in', 'former', 'forty', "'re", 'serious', 'hers', 'could', 'against', 'him', 'noone', 'on', 'anyone', 'and', 'ourselves', 'side', 'when', 'for', 'hundred', 'his', 'somehow', 'becoming', 'four', 'almost', 'who', 'thereupon', 'among', 'namely', 'herein', 'several', 'anything', 'me', 'somewhere', 'meanwhile', 'those', 'amongst', 'whereas', 'most', 'seems', 'to', 'ca', 'bottom', 'except', 'same', '‘ve', '‘re', 'must', 'some', 'been', 'quite', 'whenever', 'thence', 'there', 'around', 'after', 'together', 'eight', 'had', 'however', 'n‘t', 'thereafter', 'anyway', 'herself', 'is', 'an', 'twelve', 'thus', 'themselves'}

# %% [markdown]
# # Sentiment analysis

# %%
from textblob import TextBlob
import matplotlib.pyplot as plt
import pandas as pd
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
import re

data = pd.read_csv('test_data.tsv', delimiter = '\t')

# Shape
data
# Out:
#     ID                                             Review
# 0    1   The product is missing. It is the worst service.
# 1    2                      It is a good quality product.
# 2    3  There is a delay of product delivery. Not reco...
# 3    4                      Highly recommend the product!
# 4    5                              Not worth buying it!!
# 5    6                                    Nice and cheap!
# 6    7                                  @It is very nice.
# 7    8  I have been using this from 10 days and the pr...
# 8    9   The product is broken after 1 day. Don't buy it!
# 9   10                              Amazing     product!"
# 10  11
# 11  12                                                NaN

# %%
review = data['Review']
review
# Out:
# 0      The product is missing. It is the worst service.
# 1                         It is a good quality product.
# 2     There is a delay of product delivery. Not reco...
# 3                         Highly recommend the product!
# 4                                 Not worth buying it!!
# 5                                       Nice and cheap!
# 6                                     @It is very nice.
# 7     I have been using this from 10 days and the pr...
# 8      The product is broken after 1 day. Don't buy it!
# 9                                 Amazing     product!"
# 10
# 11                                                  NaN
# Name: Review, dtype: object

# %%
# Check for the existence of NaN values in a cell:
data.isnull().sum()
# Out:
# ID        0
# Review    1
# dtype: int64

# %%
data.dropna(inplace=True)

data
# Out:
#     ID                                             Review
# 0    1   The product is missing. It is the worst service.
# 1    2                      It is a good quality product.
# 2    3  There is a delay of product delivery. Not reco...
# 3    4                      Highly recommend the product!
# 4    5                              Not worth buying it!!
# 5    6                                    Nice and cheap!
# 6    7                                  @It is very nice.
# 7    8  I have been using this from 10 days and the pr...
# 8    9   The product is broken after 1 day. Don't buy it!
# 9   10                              Amazing     product!"
# 10  11

# %%
r=0
blanks = []  # start with an empty list

for i in data['Review']:
  
  if i.isspace():
    blanks.append(r)
    print(r)
    
  r=r+1
  
        
blanks
# Out:
# 10
# [10]

# %%
data.drop(blanks, inplace=True)

data
# Out:
#    ID                                             Review
# 0   1   The product is missing. It is the worst service.
# 1   2                      It is a good quality product.
# 2   3  There is a delay of product delivery. Not reco...
# 3   4                      Highly recommend the product!
# 4   5                              Not worth buying it!!
# 5   6                                    Nice and cheap!
# 6   7                                  @It is very nice.
# 7   8  I have been using this from 10 days and the pr...
# 8   9   The product is broken after 1 day. Don't buy it!
# 9  10                              Amazing     product!"

# %%
def clean_data(text):
    return ' '.join(re.sub("(@[a-zA-Z0-9]+)|([^0-9A-Za-z])|(https://[\w.]+/[\w]+)", " ", text).split())

data['cleaned_data'] = data['Review'].apply(clean_data)

# %%
data
# Out:
#    ID                                             Review  \
# 0   1   The product is missing. It is the worst service.
# 1   2                      It is a good quality product.
# 2   3  There is a delay of product delivery. Not reco...
# 3   4                      Highly recommend the product!
# 4   5                              Not worth buying it!!
# 5   6                                    Nice and cheap!
# 6   7                                  @It is very nice.
# 7   8  I have been using this from 10 days and the pr...
# 8   9   The product is broken after 1 day. Don't buy it!
# 9  10                              Amazing     product!"
#
#                                         cleaned_data
# 0     The product is missing It is the worst service
# 1                       It is a good quality product
# 2  There is a delay of product delivery Not recom...
# 3                       Highly recommend the product
# 4                                Not worth buying it
# 5                                     Nice and cheap
# 6                                       is very nice
# 7  I have been using this from 10 days and the pr...
# 8     The product is broken after 1 day Don t buy it
# 9                                    Amazing product

# %%
def drop_numbers(list_text):
    list_text_new = []
    for i in list_text:
        if not re.search('\d', i):
            list_text_new.append(i)
    return ''.join(list_text_new)

data['cleaned_data'] = data['cleaned_data'].apply(drop_numbers)

# %%
data
# Out:
#    ID                                             Review  \
# 0   1   The product is missing. It is the worst service.
# 1   2                      It is a good quality product.
# 2   3  There is a delay of product delivery. Not reco...
# 3   4                      Highly recommend the product!
# 4   5                              Not worth buying it!!
# 5   6                                    Nice and cheap!
# 6   7                                  @It is very nice.
# 7   8  I have been using this from 10 days and the pr...
# 8   9   The product is broken after 1 day. Don't buy it!
# 9  10                              Amazing     product!"
#
#                                         cleaned_data
# 0     The product is missing It is the worst service
# 1                       It is a good quality product
# 2  There is a delay of product delivery Not recom...
# 3                       Highly recommend the product
# 4                                Not worth buying it
# 5                                     Nice and cheap
# 6                                       is very nice
# 7  I have been using this from  days and the prod...
# 8      The product is broken after  day Don t buy it
# 9                                    Amazing product

# %%
# changing all the words of the reviews column to lowercase letters
# From library word_tokenize
import nltk
nltk.download('punkt')

def lower_case(text):
    text_words = word_tokenize(text)
    text_words_lower = [x.lower() for x in text_words]
    return ' '.join(text_words_lower)

data['cleaned_data'] = data['cleaned_data'].apply(lower_case)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\vpp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
data
# Out:
#    ID                                             Review  \
# 0   1   The product is missing. It is the worst service.
# 1   2                      It is a good quality product.
# 2   3  There is a delay of product delivery. Not reco...
# 3   4                      Highly recommend the product!
# 4   5                              Not worth buying it!!
# 5   6                                    Nice and cheap!
# 6   7                                  @It is very nice.
# 7   8  I have been using this from 10 days and the pr...
# 8   9   The product is broken after 1 day. Don't buy it!
# 9  10                              Amazing     product!"
#
#                                         cleaned_data
# 0     the product is missing it is the worst service
# 1                       it is a good quality product
# 2  there is a delay of product delivery not recom...
# 3                       highly recommend the product
# 4                                not worth buying it
# 5                                     nice and cheap
# 6                                       is very nice
# 7  i have been using this from days and the produ...
# 8       the product is broken after day don t buy it
# 9                                    amazing product

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\vpp\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
lemmatizer = WordNetLemmatizer()

def lemmatise(text):
    text_tokens = word_tokenize(text)
    text_lemm = [lemmatizer.lemmatize(word) for word in text_tokens]
    return ' '.join(text_lemm)

data['cleaned_data'] = data['cleaned_data'].apply(lemmatise)

# %%
data
# Out:
#    ID                                             Review  \
# 0   1   The product is missing. It is the worst service.
# 1   2                      It is a good quality product.
# 2   3  There is a delay of product delivery. Not reco...
# 3   4                      Highly recommend the product!
# 4   5                              Not worth buying it!!
# 5   6                                    Nice and cheap!
# 6   7                                  @It is very nice.
# 7   8  I have been using this from 10 days and the pr...
# 8   9   The product is broken after 1 day. Don't buy it!
# 9  10                              Amazing     product!"
#
#                                         cleaned_data
# 0     the product is missing it is the worst service
# 1                       it is a good quality product
# 2  there is a delay of product delivery not recom...
# 3                       highly recommend the product
# 4                                not worth buying it
# 5                                     nice and cheap
# 6                                       is very nice
# 7  i have been using this from day and the produc...
# 8       the product is broken after day don t buy it
# 9                                    amazing product

# %% [markdown]
# # Stop Words removal
# Remove available stopwords
#
#
# Also remove any unnecessary words as well by extending the stopwords

# %%
data
# Out:
#    ID                                             Review  \
# 0   1   The product is missing. It is the worst service.
# 1   2                      It is a good quality product.
# 2   3  There is a delay of product delivery. Not reco...
# 3   4                      Highly recommend the product!
# 4   5                              Not worth buying it!!
# 5   6                                    Nice and cheap!
# 6   7                                  @It is very nice.
# 7   8  I have been using this from 10 days and the pr...
# 8   9   The product is broken after 1 day. Don't buy it!
# 9  10                              Amazing     product!"
#
#                                         cleaned_data
# 0     the product is missing it is the worst service
# 1                       it is a good quality product
# 2  there is a delay of product delivery not recom...
# 3                       highly recommend the product
# 4                                not worth buying it
# 5                                     nice and cheap
# 6                                       is very nice
# 7  i have been using this from day and the produc...
# 8       the product is broken after day don t buy it
# 9                                    amazing product

# %%
# Lets calculate the Polarity of the Reviews
def get_polarity(text):
    textblob = TextBlob(str(text))
    pol = textblob.sentiment.polarity
    print(pol)
    if(pol==0):
        return "Neutral"
    elif(pol>0.1 and pol<=1):
        return "Positive"
    elif(pol>-1 and pol<=-0.1):
        return "Negative"
    
data['polarity'] = data['cleaned_data'].apply(get_polarity)
# Out:
# -0.6
# 0.7
# 0.0
# 0.16
# -0.15
# 0.5
# 0.78
# 0.78
# -0.4
# 0.6000000000000001

# %%
data['polarity'].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='polarity'>

# %%
data['polarity'].value_counts()
# Out:
# polarity
# Positive    6
# Negative    3
# Neutral     1
# Name: count, dtype: int64

# %% [markdown]
# # Classification

# %%
from textblob import TextBlob
import matplotlib.pyplot as plt
import pandas as pd
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
import re

data = pd.read_csv('test_data_class.tsv', delimiter = '\t')

data
# Out:
#     ID                                             Review Label
# 0    1   The product is missing. It is the worst service.   neg
# 1    2                      It is a good quality product.   pos
# 2    3  There is a delay of product delivery. Not reco...   neg
# 3    4           Highly recommend the product. It & nice!   pos
# 4    5                              Not worth buying it!!   neg
# 5    6                                    Nice and cheap!   pos
# 6    7                                  @It is very nice.   pos
# 7    8  I have been using this from 10 days and the pr...   pos
# 8    9   The product is broken after 1 day. Don't buy it!   neg
# 9   10                                   Amazing product!   pos
# 10  11                                                NaN   NaN
# 11  12                                                      NaN

# %%
data.isnull().sum()
# Out:
# ID        0
# Review    1
# Label     2
# dtype: int64

# %%
data.head()
# Out:
#    ID                                             Review Label
# 0   1   The product is missing. It is the worst service.   neg
# 1   2                      It is a good quality product.   pos
# 2   3  There is a delay of product delivery. Not reco...   neg
# 3   4           Highly recommend the product. It & nice!   pos
# 4   5                              Not worth buying it!!   neg

# %%
data.dropna(inplace=True)

data
# Out:
#    ID                                             Review Label
# 0   1   The product is missing. It is the worst service.   neg
# 1   2                      It is a good quality product.   pos
# 2   3  There is a delay of product delivery. Not reco...   neg
# 3   4           Highly recommend the product. It & nice!   pos
# 4   5                              Not worth buying it!!   neg
# 5   6                                    Nice and cheap!   pos
# 6   7                                  @It is very nice.   pos
# 7   8  I have been using this from 10 days and the pr...   pos
# 8   9   The product is broken after 1 day. Don't buy it!   neg
# 9  10                                   Amazing product!   pos

# %%
r=0
blanks = []  # start with an empty list

for i in data['Review']:
    if i.isspace():
        blanks.append(r)

    r=r+1
        
blanks

# %%
data

# %%
def clean_data(text):
    return ' '.join(re.sub("(@[a-zA-Z0-9]+)|([^0-9A-Za-z])|(https://[\w.]+/[\w]+)", " ", text).split())

data['cleaned_data'] = data['Review'].apply(clean_data)

def drop_numbers(list_text):
    list_text_new = []
    for i in list_text:
        if not re.search('\d', i):
            list_text_new.append(i)
    return ''.join(list_text_new)

data['cleaned_data'] = data['cleaned_data'].apply(drop_numbers)

# %%
data
# Out:
#    ID                                             Review Label  \
# 0   1   The product is missing. It is the worst service.   neg
# 1   2                      It is a good quality product.   pos
# 2   3  There is a delay of product delivery. Not reco...   neg
# 3   4           Highly recommend the product. It & nice!   pos
# 4   5                              Not worth buying it!!   neg
# 5   6                                    Nice and cheap!   pos
# 6   7                                  @It is very nice.   pos
# 7   8  I have been using this from 10 days and the pr...   pos
# 8   9   The product is broken after 1 day. Don't buy it!   neg
# 9  10                                   Amazing product!   pos
#
#                                         cleaned_data
# 0     The product is missing It is the worst service
# 1                       It is a good quality product
# 2  There is a delay of product delivery Not recom...
# 3               Highly recommend the product It nice
# 4                                Not worth buying it
# 5                                     Nice and cheap
# 6                                       is very nice
# 7  I have been using this from  days and the prod...
# 8      The product is broken after  day Don t buy it
# 9                                    Amazing product

# %%
data['Label'].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='Label'>

# %%
# Classification begins here

from sklearn.model_selection import train_test_split

X = data['cleaned_data']
y = data['Label']

# change your train and test size to check accuracy
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
# Pipeline

from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC

# Creating classifier With data of vectors TFIDF
text_clf_lsvc = Pipeline([('tfidf', TfidfVectorizer()),
                     ('clf', LinearSVC()),
])

# %% [markdown]
# # Try Randomforestclassifier

# %%
# Training 
text_clf_lsvc.fit(X_train, y_train)
# Out:
# C:\Users\vpp\AppData\Local\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# Pipeline(steps=[('tfidf', TfidfVectorizer()), ('clf', LinearSVC())])

# %%
# Testing
predictions = text_clf_lsvc.predict(X_test)

# %%
from sklearn import metrics

# Print the overall accuracy
print(metrics.accuracy_score(y_test,predictions))
# Out:
# 0.5
