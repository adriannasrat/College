# %% [markdown]
# # **Linguistic Features:**
#
# Text: The original word text.
#
# Lemma: The base form of the word.
#
# POS: The simple POS part-of-speech tag.
#
# Tag: The detailed part-of-speech tag. ("DT" for determiner, "VBZ" for verb, "NN" for noun)
#
# Dep: Syntactic dependency, i.e. the relation between tokens.
#
# Shape: The word shape – capitalization, punctuation, digits.
#
# is alpha: Is the token an alphabetic character?
#
# is stop: Is the token part of a stop list, i.e. the most common words of the language?

# %%
import spacy
print(spacy.__version__)
# Out:
# 3.8.5

# %%
try:
    nlp = spacy.load("en_core_web_sm")
    print("Model loaded successfully!")
except OSError as e:
    print(e)
# Out:
# Model loaded successfully!

# %%
# Spacy, nltk, textblob, pandas, numpy, matplotlib, scikit-learn
# Download this in prompt: python -m spacy download en
# There are a few more downloads below

import spacy

nlp_model = spacy.load("en_core_web_sm")

# Create a Doc object
doc = nlp_model(u"Apple is one of the biggest companies in the world")

# %%
# Print each token separately
for token in doc:
    print(token.text, token.pos_, token.dep_, token.is_stop)
# Out:
# Apple PROPN nsubj False
# is AUX ROOT True
# one NUM attr True
# of ADP prep True
# the DET det True
# biggest ADJ amod False
# companies NOUN pobj False
# in ADP prep True
# the DET det True
# world NOUN pobj False

# %%
doc[2].tag_
# Out:
# 'CD'

# %%
# tag_; text; lemma_ ; pos_ ; 
 #   tag_; shape_; is_alpha;
 #   is_stop

# %%
doc1 = nlp_model(u'Although commmonly attributed to John Lennon from his song "Beautiful Boy", \
the phrase "Life is what happens to us while we are making other plans" was written by \
cartoonist Allen Saunders and published in Reader\'s Digest in 1957, when Lennon was 17.')
doc1
# Out:
# Although commmonly attributed to John Lennon from his song "Beautiful Boy", the phrase "Life is what happens to us while we are making other plans" was written by cartoonist Allen Saunders and published in Reader's Digest in 1957, when Lennon was 17.

# %%
life_quote = doc1[16:30]
print(life_quote)
# Out:
# "Life is what happens to us while we are making other plans"

# %%
# span is a slice of document or sentence
type(life_quote)
# Out:
# spacy.tokens.span.Span

# %% [markdown]
# # Tokenization

# %%
mystring = nlp_model(u"One is a number")
print(mystring)

# Create a string that includes opening and closing quotation marks
mystring1 = nlp_model(u'We\'re here to help! email support@oursite.com or visit us at http://www.oursite.com!')
print(mystring1)
# Out:
# One is a number
# We're here to help! email support@oursite.com or visit us at http://www.oursite.com!

# %%
# Explore tokens
doc3 = nlp_model(mystring)

for t in doc3:
    print(t.text)
# Out:
# One
# is
# a
# number

# %%
doc4 = nlp_model(mystring1)

for token in doc4:
    print(token)
# Out:
# We
# 're
# here
# to
# help
# !
# email
# support@oursite.com
# or
# visit
# us
# at
# http://www.oursite.com
# !

# %%
# count of tokens
len(doc4)
# Out:
# 14

# %% [markdown]
# # Named entity

# %%
doc5 = nlp_model(u'Apple is one of the fruits')

for token in doc5:
    print(token.text, end=' | ')

print('\n----')

for ent in doc5.ents:
    print(ent.text+' - '+ent.label_)
# Out:
# Apple | is | one | of | the | fruits |
# ----
# Apple - ORG

# %%
# Lemmatization/stemming

doc6 = nlp_model(u"Mapping a GIS tool")

for token in doc6:
    print(token.text, '\t', token.pos_, '\t', token.lemma_)
# Out:
# Mapping 	 VERB 	 map
# a 	 DET 	 a
# GIS 	 NOUN 	 gis
# tool 	 NOUN 	 tool

# %%
# Stop words
print(nlp_model.Defaults.stop_words)
# Out:
# {'ca', 'none', 'all', 'becoming', 'both', 'she', 'nine', 'per', 'hereupon', 'our', '’s', 'himself', 'ten', 'via', 'which', 'at', 'me', 'should', 'otherwise', 'so', 'what', "'m", 'take', 'its', 'one', 'unless', 'from', 'here', 'front', 'moreover', 'no', 'cannot', 'by', 'beforehand', 'just', 'is', 'before', 'go', 'someone', 'whither', 'perhaps', 'somewhere', 'always', 'some', 'had', '’m', 'nobody', 'them', 'we', 'ours', 'put', "'s", 'across', 'above', 'same', 'nothing', 'sometime', 'yet', 'towards', 'hence', 'how', 'it', 'latter', 'four', 'either', 'still', 'where', 'as', 'i', 'name', '’d', 'full', 'afterwards', 'amount', 'behind', 'mine', 'less', 'hers', 'those', 'thence', 'call', 'up', 'be', 'between', 'over', 'each', 'give', 'only', 'doing', 'every', 'after', 'fifteen', 'due', 'if', 'say', 'there', 'part', 'been', 'this', 'off', 'again', 'whatever', 'however', 'among', 'somehow', 'everyone', 'almost', 'enough', 'top', 'further', 'ever', 'of', 'will', 'whereupon', 'last', 'than', 'out', 'see', 'into', 'her', 'whole', 'anywhere', 'upon', 'us', '’ll', 'n’t', 'anyhow', 'everywhere', 'most', 'next', 'first', 'why', 'meanwhile', 'you', 'other', 'my', 'very', 'third', 'alone', 'except', 'mostly', 'whoever', 'everything', 'are', 'hundred', '‘ve', '‘m', '’re', 'these', 'within', 'thereby', 'who', 'although', 'side', 'below', 'themselves', 'empty', 'their', 'rather', 'several', 'six', 'eleven', 'amongst', 'seemed', 'has', 'herein', 'thru', 'besides', 'namely', 'noone', 'through', 'were', 'thereafter', 'formerly', 'anyone', 'regarding', 'may', 'forty', "'ll", 'the', '’ve', 'became', 'nowhere', 'with', 'whose', 'a', 'whether', 'too', 'beside', 'because', 'onto', 'fifty', 'anyway', 'already', 'was', '‘s', 'beyond', 'yourself', 'seems', 'am', 'much', 'since', 'least', 'using', 'quite', 'n‘t', 'former', 'please', 'down', 'well', 'without', 'until', 'once', "'ve", 'though', 'your', 'yourselves', 'along', 'two', 'therein', 'sixty', 'about', 'nevertheless', 'thereupon', 'under', 'throughout', "n't", 'an', 'being', 'often', 'really', 'any', 'whom', 'do', 'twenty', 'when', 'latterly', 'for', 'make', 'did', 'hereby', 'eight', 'seeming', 'whenever', 'such', 'in', 'herself', 'he', 'they', 'else', 'become', 'myself', 'whence', 'thus', 'itself', 'more', 'would', 'indeed', 'might', 'move', 'many', 'can', 'another', 'that', 'whereafter', 'now', 'twelve', 'anything', 'hereafter', 'seem', 'even', 'neither', "'d", 'and', 'therefore', 'sometimes', 'against', 'done', 'few', '‘ll', 'together', 'not', 'never', 'then', 'could', 'whereby', 'wherever', 'or', 'elsewhere', 'his', 'to', 'ourselves', 'wherein', 'yours', 'must', 'while', 'on', '‘re', '‘d', 'three', 'made', 'others', 'nor', 'bottom', 'whereas', 'used', 'around', 'but', 'own', 'five', 'toward', 'during', "'re", 'keep', 'various', 'does', 'back', 'have', 'something', 'becomes', 're', 'also', 'show', 'get', 'serious', 'him'}

# %% [markdown]
# # Sentiment analysis

# %%
from textblob import TextBlob
import matplotlib.pyplot as plt
import pandas as pd
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
import re

data = pd.read_csv('test_data.tsv', delimiter = '\t')

# Shape
data
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 from textblob import TextBlob
#       2 import matplotlib.pyplot as plt
#       3 import pandas as pd
#
# ModuleNotFoundError: No module named 'textblob'

# %%
review = data['Review']
review
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 review = data['Review']
#       2 review
#
# NameError: name 'data' is not defined

# %%
# Check for the existence of NaN values in a cell:
data.isnull().sum()

# %%
data.dropna(inplace=True)

data

# %%
r=0
blanks = []  # start with an empty list

for i in data['Review']:
  
  if i.isspace():
    blanks.append(r)
    print(r)
    
  r=r+1
  
        
blanks

# %%
data.drop(blanks, inplace=True)

data

# %%
def clean_data(text):
    return ' '.join(re.sub("(@[a-zA-Z0-9]+)|([^0-9A-Za-z])|(https://[\w.]+/[\w]+)", " ", text).split())

data['cleaned_data'] = data['Review'].apply(clean_data)

# %%
data

# %%
def drop_numbers(list_text):
    list_text_new = []
    for i in list_text:
        if not re.search('\d', i):
            list_text_new.append(i)
    return ''.join(list_text_new)

data['cleaned_data'] = data['cleaned_data'].apply(drop_numbers)

# %%
data

# %%
# changing all the words of the reviews column to lowercase letters
# From library word_tokenize
import nltk
nltk.download('punkt')

def lower_case(text):
    text_words = word_tokenize(text)
    text_words_lower = [x.lower() for x in text_words]
    return ' '.join(text_words_lower)

data['cleaned_data'] = data['cleaned_data'].apply(lower_case)

# %%
data

# %%
import nltk
nltk.download('wordnet')

# %%
lemmatizer = WordNetLemmatizer()

def lemmatise(text):
    text_tokens = word_tokenize(text)
    text_lemm = [lemmatizer.lemmatize(word) for word in text_tokens]
    return ' '.join(text_lemm)

data['cleaned_data'] = data['cleaned_data'].apply(lemmatise)

# %%
data

# %% [markdown]
# # Stop Words removal
# Remove available stopwords
#
#
# Also remove any unnecessary words as well by extending the stopwords

# %%
data

# %%
# Lets calculate the Polarity of the Reviews
def get_polarity(text):
    textblob = TextBlob(str(text))
    pol = textblob.sentiment.polarity
    print(pol)
    if(pol==0):
        return "Neutral"
    elif(pol>0.1 and pol<=1):
        return "Positive"
    elif(pol>-1 and pol<=-0.1):
        return "Negative"
    
data['polarity'] = data['cleaned_data'].apply(get_polarity)

# %%
data['polarity'].value_counts().plot(kind='barh')

# %%
data['polarity'].value_counts()

# %% [markdown]
# # Classification

# %%
from textblob import TextBlob
import matplotlib.pyplot as plt
import pandas as pd
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
import re

data = pd.read_csv('test_data_class.tsv', delimiter = '\t')

data

# %%
data.isnull().sum()

# %%
data.head()

# %%
data.dropna(inplace=True)

data

# %%
r=0
blanks = []  # start with an empty list

for i in data['Review']:
    if i.isspace():
        blanks.append(r)

    r=r+1
        
blanks

# %%
data

# %%
def clean_data(text):
    return ' '.join(re.sub("(@[a-zA-Z0-9]+)|([^0-9A-Za-z])|(https://[\w.]+/[\w]+)", " ", text).split())

data['cleaned_data'] = data['Review'].apply(clean_data)

def drop_numbers(list_text):
    list_text_new = []
    for i in list_text:
        if not re.search('\d', i):
            list_text_new.append(i)
    return ''.join(list_text_new)

data['cleaned_data'] = data['cleaned_data'].apply(drop_numbers)

# %%
data

# %%
data['Label'].value_counts().plot(kind='barh')

# %%
# Classification begins here

from sklearn.model_selection import train_test_split

X = data['cleaned_data']
y = data['Label']

# change your train and test size to check accuracy
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
# Pipeline

from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC

# Creating classifier With data of vectors TFIDF
text_clf_lsvc = Pipeline([('tfidf', TfidfVectorizer()),
                     ('clf', LinearSVC()),
])

# %% [markdown]
# # Try Randomforestclassifier

# %%
# Training 
text_clf_lsvc.fit(X_train, y_train)

# %%
# Testing
predictions = text_clf_lsvc.predict(X_test)

# %%
from sklearn import metrics

# Print the overall accuracy
print(metrics.accuracy_score(y_test,predictions))
